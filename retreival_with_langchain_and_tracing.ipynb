# %%
import os
import pandas as pd
import numpy as np
import nest_asyncio
from langchain.chains import RetrievalQA
from langchain.retrievers import KNNRetriever
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.chat_models import ChatOllama
from urllib.request import urlopen
import json
# from langchain_openai import ChatOpenAI, OpenAIEMbeddings
from phoenix.evals import (
    HallucinationEvaluator,
    OpenAIModel,
    QAEvaluator,
    RelevanceEvaluator,
    run_evals, 
)
from langchain_huggingface import HuggingFaceEmbeddings
from openai import OpenAI
import phoenix as px
from phoenix.session.evaluation import get_qa_with_reference, get_retrieved_documents
from phoenix.trace import DocumentEvaluations, SpanEvaluations
from phoenix.trace.langchain import LangChainInstrumentor
from tqdm import tqdm, tqdm_notebook

nest_asyncio.apply()

# %%
session = px.launch_app()
# Out:
# 🌍 To view the Phoenix app in your browser, visit http://localhost:6006/
# 📖 For more information on how to use Phoenix, check out https://docs.arize.com/phoenix

# %%
llm = ChatOllama(model='phi3', temperature=0.0)
embedding_model = HuggingFaceEmbeddings(
    model_name='mixedbread-ai/mxbai-embed-large-v1',
    model_kwargs={'device': 'cpu'},
    encode_kwargs={'normalize_embeddings': False}
)

# %%
df = pd.read_parquet(
    "http://storage.googleapis.com/arize-phoenix-assets/datasets/"
    "unstructured/llm/context-retrieval/langchain/database.parquet"
)
print(df.shape)
df.head(3)
# Out:
# (1086, 2)
#                                                 text  \
# 0  \nAccess tutorials of what's possible with Ari...
# 1  \n{% hint style="info" %}\nYour model type det...
# 2  \nExamples for logging explainability metrics....
#
#                                          text_vector
# 0  [-0.0036313518733896957, 0.0026182831234325553...
# 1  [-0.006279695251247202, -0.0005314257337369415...
# 2  [-0.007306394403318994, 0.0007199545863166625,...

# %%
# df['text_embedding_bge'] = df.text.apply(lambda x: embedding_model.embed_query(x))
embedding_model.embed_query(df.iloc[2]['text'])
# Out:
# [0.5222705006599426,
#  0.3841533660888672,
#  -0.15000851452350616,
#  0.2376929521560669,
#  -0.43989720940589905,
#  0.006094262003898621,
#  -0.8401291966438293,
#  -0.20802666246891022,
#  -0.12276878952980042,
#  0.6840602159500122,
#  -0.20088237524032593,
#  0.7620967626571655,
#  -0.014210522174835205,
#  -0.4881494641304016,
#  0.04106529802083969,
#  0.5747261047363281,
#  -0.38870906829833984,
#  -0.3908386528491974,
#  -0.9535424709320068,
#  -0.340037077665329,
#  0.6715689301490784,
#  0.5610557794570923,
#  -0.9577788710594177,
#  -0.40011611580848694,
#  -0.45081111788749695,
#  0.902858316898346,
#  0.31196388602256775,
#  -0.12017923593521118,
#  0.6604458093643188,
#  0.3868192732334137,
#  -0.15026453137397766,
#  0.1389276087284088,
#  -0.11175327003002167,
#  -1.4587552547454834,
#  -0.08540473133325577,
#  -0.3283596932888031,
#  0.6989537477493286,
#  -0.18379484117031097,
#  -0.334386944770813,
#  -0.8390719890594482,
#  -0.34405890107154846,
#  0.266710102558136,
#  0.8795782327651978,
#  -1.0262759923934937,
#  -0.8161568641662598,
#  -0.2994120121002197,
#  0.02108580619096756,
#  -0.26796960830688477,
#  0.13653922080993652,
#  -0.301777720451355,
#  -0.6464815139770508,
#  0.2696726620197296,
#  0.2886580228805542,
#  -0.6409622430801392,
#  0.05304613709449768,
#  -0.39029473066329956,
#  -0.2786632478237152,
#  0.48005741834640503,
#  0.4230315685272217,
#  -0.23568621277809143,
#  -0.8576409816741943,
#  -0.1549055278301239,
#  0.1836419701576233,
#  -0.06703934818506241,
#  0.044421859085559845,
#  0.21407842636108398,
#  -0.051174990832805634,
#  -0.2715262472629547,
#  0.8389813899993896,
#  -0.10929110646247864,
#  0.25967127084732056,
#  0.2899686396121979,
#  0.407363623380661,
#  -0.23744866251945496,
#  -0.347607284784317,
#  -0.59331876039505,
#  0.06764453649520874,
#  -0.20061273872852325,
#  0.21456435322761536,
#  0.6817715167999268,
#  0.24613715708255768,
#  -0.7065626382827759,
#  0.14039818942546844,
#  -0.07926873862743378,
#  -0.19117623567581177,
#  -0.3921709358692169,
#  -0.21229486167430878,
#  0.2075393944978714,
#  -0.32975032925605774,
#  0.8395759463310242,
#  0.5045139789581299,
#  0.05266633257269859,
#  0.6797409653663635,
#  -1.296517252922058,
#  0.029915273189544678,
#  -0.8232547640800476,
#  0.1494416743516922,
#  -0.7523929476737976,
#  -0.9286458492279053,
#  0.028175007551908493,
#  -0.15733680129051208,
#  -0.5779057741165161,
#  -0.3383546471595764,
#  0.5148431062698364,
#  0.07990310341119766,
#  -0.27766290307044983,
#  -0.27200841903686523,
#  -0.26164838671684265,
#  0.07300473749637604,
#  0.4128108620643616,
#  -0.091991126537323,
#  0.3613933324813843,
#  0.0890265554189682,
#  -0.6152247190475464,
#  -0.04163026064634323,
#  ...]

# %%
tqdm.pandas()
df['text_vector_bge'] = df.progress_apply(lambda x: embedding_model.embed_query(x['text']), axis=1)
# Out:
# 100%|██████████| 1086/1086 [11:05<00:00,  1.63it/s]

# %%
df.to_feather("./data/arize_phoenix_dataset_bge.feather")

# %%
knn_retriever = KNNRetriever(
    index=np.stack(df['text_vector_bge']),
    texts = df['text'].tolist(),
    embeddings=embedding_model
)

# %%
chain_type = "stuff"

chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type=chain_type,
    retriever=knn_retriever,
    metadata={'application_type': 'question_answering'}
)

# %%
LangChainInstrumentor().instrument()
# Out:
# WARNI [opentelemetry.instrumentation.instrumentor] Attempting to instrument while already instrumented

# %%
url = "http://storage.googleapis.com/arize-phoenix-assets/datasets/unstructured/llm/context-retrieval/arize_docs_queries.jsonl"
queries = []
with urlopen(url) as response:
    for line in response:
        line = line.decode("utf-8").strip()
        data = json.loads(line)
        queries.append(data["query"])
queries[:10]
# Out:
# ['How do I use the SDK to upload a ranking model?',
#  'What drift metrics are supported in Arize?',
#  'Does Arize support batch models?',
#  'Does Arize support training data?',
#  'How do I configure a threshold if my data has seasonality trends?',
#  'How are clusters in the UMAP calculated? When are the clusters refreshed?',
#  'How does Arize calculate AUC?',
#  'Can I send truth labels to Arize separtely? ',
#  'How do I send embeddings to Arize?',
#  'Can I copy a dashboard']

# %%
for query in tqdm(queries[:10]):
    chain.invoke(query)
# Out:
# 100%|██████████| 10/10 [02:18<00:00, 13.83s/it]

# %% [markdown]
# # Export and Evaluate the trace data

# %%
queries_df = get_qa_with_reference(px.Client())
retrieved_documents_df = get_retrieved_documents(px.Client())

# %%
queries_df.head()
# Out:
#                                                               input  \
# context.span_id
# 47bd3278edb320e3    How do I use the SDK to upload a ranking model?
# ae5456d885ec0720         What drift metrics are supported in Arize?
# 4c72e90563eb7d27                   Does Arize support batch models?
# 56624d801f1ffe88                  Does Arize support training data?
# fc61f64b9fb4c6a0  How do I configure a threshold if my data has ...
#
#                                                              output  \
# context.span_id
# 47bd3278edb320e3   To upload your ranking model using the ARIZE ...
# ae5456d885ec0720   In Arize, users have access to a variety of d...
# 4c72e90563eb7d27   Yes, Arize supports both single record and ba...
# 56624d801f1ffe88   No, the context provided does not explicitly ...
# fc61f64b9fb4c6a0   To accommodate for seasonality in your time s...
#
#                                                           reference
# context.span_id
# 47bd3278edb320e3  \n```python\nfrom arize.utils.types import Env...
# ae5456d885ec0720  \nArize calculates drift metrics such as Popul...
# 4c72e90563eb7d27  \nArize helps you visualize your model perform...
# 56624d801f1ffe88  \nArize integrates with your ML stack, no matt...
# fc61f64b9fb4c6a0  \nWith auto thresholds turned off, set the thr...

# %%
retrieved_documents_df.head()
# Out:
#                                                     context.trace_id  \
# context.span_id  document_position
# d034eb9eb2a821a6 0                  1d03007b975be7de51bae7b5a3190eae
#                  1                  1d03007b975be7de51bae7b5a3190eae
#                  2                  1d03007b975be7de51bae7b5a3190eae
#                  3                  1d03007b975be7de51bae7b5a3190eae
# 493f7d6338b0c42e 0                  9f95ac74603cb6b0eca563ed92bd45d4
#
#                                                                               input  \
# context.span_id  document_position
# d034eb9eb2a821a6 0                  How do I use the SDK to upload a ranking model?
#                  1                  How do I use the SDK to upload a ranking model?
#                  2                  How do I use the SDK to upload a ranking model?
#                  3                  How do I use the SDK to upload a ranking model?
# 493f7d6338b0c42e 0                       What drift metrics are supported in Arize?
#
#                                                                             reference
# context.span_id  document_position
# d034eb9eb2a821a6 0                  \n```python\nfrom arize.utils.types import Env...
#                  1                  response = arize_client.log(\n    model_id="de...
#                  2                  response = arize_client.log(\n    model_id="de...
#                  3                  response = arize_client.log(\n    model_id="de...
# 493f7d6338b0c42e 0                  \nArize calculates drift metrics such as Popul...

# %%
eval_model = OpenAIModel(model='phi3', base_url='http://localhost:11434/v1', api_key='ollama')
hallucination_evaluator = HallucinationEvaluator(eval_model)
qa_correctness_evaluator = QAEvaluator(eval_model)
relevance_evaluator = RelevanceEvaluator(eval_model)

hallucination_eval_df, qa_correctness_eval_df = run_evals(
    dataframe=queries_df,
    evaluators=[hallucination_evaluator, qa_correctness_evaluator],
    provide_explanation=True,
)
relevance_eval_df = run_evals(
    dataframe=retrieved_documents_df,
    evaluators=[relevance_evaluator],
    provide_explanation=True,
)[0]

px.Client().log_evaluations(
    SpanEvaluations(eval_name="Hallucination", dataframe=hallucination_eval_df),
    SpanEvaluations(eval_name="QA Correctness", dataframe=qa_correctness_eval_df),
    DocumentEvaluations(eval_name="Relevance", dataframe=relevance_eval_df),
)
# Out:
# run_evals |          | 0/20 (0.0%) | ⏳ 00:00<? | ?it/s
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# Worker timeout, requeuing
# run_evals |          | 0/40 (0.0%) | ⏳ 00:00<? | ?it/s
